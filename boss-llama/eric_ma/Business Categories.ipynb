# %%
from datetime import datetime
import os
import numpy as np
import pandas as pd
from pyspark.ml.feature import CountVectorizer, IDF, PCA, Word2Vec
from pyspark.ml.linalg import DenseVector, SparseVector, VectorUDT, Vectors
from pyspark.ml.clustering import GaussianMixture, KMeans
from pyspark.ml import Pipeline
from pyspark.sql.functions import *
from pyspark.sql.types import DateType, FloatType, IntegerType, DoubleType
spark_home = os.environ.get('SPARK_HOME', None)

import plotly
plotly.tools.set_credentials_file(username='amcire96', api_key='sej35ud4YbSOfIshhhZg')
# print(plotly.__version__)

import plotly.plotly as py
from plotly.graph_objs import *
import plotly.figure_factory as FF
import requests
requests.packages.urllib3.disable_warnings()

# %%
business = spark.read.json("/user/hduser1/Yelp/business.json").repartition(300)
print(business.count())
business = business.where(col("categories").isNotNull()).where(col("review_count")>10)
print(business.count())
business.printSchema()
business.head(5)
# Out:
# 144072
# 63104
# root
#  |-- address: string (nullable = true)
#  |-- attributes: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- business_id: string (nullable = true)
#  |-- categories: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- city: string (nullable = true)
#  |-- hours: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- is_open: long (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- name: string (nullable = true)
#  |-- neighborhood: string (nullable = true)
#  |-- postal_code: string (nullable = true)
#  |-- review_count: long (nullable = true)
#  |-- stars: double (nullable = true)
#  |-- state: string (nullable = true)
#  |-- type: string (nullable = true)
# [Row(address=u'7523 Pearl Rd', attributes=[u'Alcohol: beer_and_wine', u"Ambience: {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}", u'BikeParking: True', u'BusinessAcceptsCreditCards: True', u"BusinessParking: {'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}", u'Caters: True', u'DogsAllowed: False', u'DriveThru: False', u'GoodForKids: True', u"GoodForMeal: {'dessert': True, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': False}", u'HasTV: True', u'NoiseLevel: average', u'OutdoorSeating: False', u'RestaurantsAttire: casual', u'RestaurantsDelivery: True', u'RestaurantsGoodForGroups: True', u'RestaurantsPriceRange2: 2', u'RestaurantsReservations: True', u'RestaurantsTableService: True', u'RestaurantsTakeOut: True', u'WheelchairAccessible: True', u'WiFi: free'], business_id=u'CS2oAjAiFrJiG2HUtKJUHQ', categories=[u'Beer', u'Wine & Spirits', u'Chicken Wings', u'Salad', u'Food', u'Restaurants', u'Wine Bars', u'Nightlife', u'American (New)', u'Gluten-Free', u'Italian', u'Bars', u'Pizza', u'Sandwiches', u'American (Traditional)', u'Burgers'], city=u'Middleburg Heights', hours=[u'Monday 11:0-22:0', u'Tuesday 11:0-22:0', u'Wednesday 11:0-22:0', u'Thursday 11:0-22:0', u'Friday 11:0-22:0', u'Saturday 11:0-22:0'], is_open=1, latitude=41.3605712899, longitude=-81.8130021019, name=u'3 Brothers Pizza', neighborhood=u'', postal_code=u'44130', review_count=54, stars=4.0, state=u'OH', type=u'business'),
#  Row(address=u'10750 W McDowell Rd, Ste F-610', attributes=[u'AcceptsInsurance: True', u'ByAppointmentOnly: True'], business_id=u'mOSF-TjNwXa_EDP1yjZEqw', categories=[u'Orthodontists', u'Health & Medical', u'Pediatric Dentists', u'Dentists'], city=u'Avondale', hours=[u'Monday 7:0-16:0', u'Tuesday 7:0-16:0', u'Wednesday 7:0-16:0', u'Thursday 7:0-16:0', u'Friday 7:0-12:0'], is_open=1, latitude=33.4655303955, longitude=-112.290527344, name=u'Sun Valley Pediatric Dentistry', neighborhood=u'', postal_code=u'85392', review_count=12, stars=3.0, state=u'AZ', type=u'business'),
#  Row(address=u'Venetian Hotel & Casino, 3377 Las Vegas Blvd S, Ste 2230', attributes=[u'Alcohol: none', u'BusinessAcceptsCreditCards: True', u"BusinessParking: {'garage': True, 'street': False, 'validated': False, 'lot': True, 'valet': False}", u'Caters: False', u'DogsAllowed: False', u'GoodForKids: True', u"GoodForMeal: {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': False}", u'HasTV: False', u'NoiseLevel: loud', u'OutdoorSeating: False', u'RestaurantsAttire: casual', u'RestaurantsDelivery: False', u'RestaurantsPriceRange2: 2', u'RestaurantsReservations: False', u'RestaurantsTableService: False', u'RestaurantsTakeOut: True', u'WheelchairAccessible: True', u'WiFi: no'], business_id=u'df5IJWW0-C4AJDCS9AwtbQ', categories=[u'Italian', u'Restaurants', u'Pizza'], city=u'Las Vegas', hours=[u'Monday 8:0-23:0', u'Tuesday 8:0-23:0', u'Wednesday 8:0-23:0', u'Thursday 8:0-23:0', u'Friday 8:0-0:0', u'Saturday 8:0-0:0', u'Sunday 8:0-23:0'], is_open=0, latitude=36.1218632, longitude=-115.1696491, name=u'L.A. Italian Kitchen', neighborhood=u'The Strip', postal_code=u'89109', review_count=13, stars=2.5, state=u'NV', type=u'business'),
#  Row(address=u'5442 Walnut St', attributes=[u'Alcohol: full_bar', u"Ambience: {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}", u"BestNights: {'monday': True, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': True}", u'BikeParking: True', u'BusinessAcceptsCreditCards: True', u"BusinessParking: {'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}", u'CoatCheck: False', u'GoodForDancing: False', u'HappyHour: True', u'HasTV: True', u"Music: {'dj': False, 'background_music': True, 'no_music': False, 'karaoke': False, 'live': False, 'video': False, 'jukebox': False}", u'NoiseLevel: loud', u'OutdoorSeating: True', u'RestaurantsGoodForGroups: True', u'RestaurantsPriceRange2: 2', u'RestaurantsReservations: False', u'Smoking: outdoor'], business_id=u'CwcDRtNgjgM4pLS4o63g6A', categories=[u'Nightlife', u'Sports Bars', u'Bars'], city=u'Pittsburgh', hours=[u'Monday 11:0-2:0', u'Tuesday 11:0-2:0', u'Wednesday 11:0-2:0', u'Thursday 11:0-2:0', u'Friday 11:0-2:0', u'Saturday 11:0-2:0', u'Sunday 11:0-2:0'], is_open=1, latitude=40.4509479, longitude=-79.9338609, name=u"Mario's East Side Saloon", neighborhood=u'Shadyside', postal_code=u'15232', review_count=69, stars=3.5, state=u'PA', type=u'business'),
#  Row(address=u'1204 S Main St', attributes=[u'Alcohol: full_bar', u"Ambience: {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}", u'BikeParking: True', u'BusinessAcceptsBitcoin: False', u'BusinessAcceptsCreditCards: True', u"BusinessParking: {'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}", u'Caters: True', u'DogsAllowed: False', u'GoodForKids: True', u"GoodForMeal: {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': False}", u'HasTV: True', u'NoiseLevel: average', u'OutdoorSeating: True', u'RestaurantsAttire: casual', u'RestaurantsDelivery: False', u'RestaurantsGoodForGroups: True', u'RestaurantsPriceRange2: 2', u'RestaurantsReservations: True', u'RestaurantsTableService: True', u'RestaurantsTakeOut: True', u'WheelchairAccessible: True', u'WiFi: free'], business_id=u'a192hdM0_UVCYLwPJv1Qwg', categories=[u'Seafood', u'Restaurants', u'Mexican'], city=u'Las Vegas', hours=[u'Monday 7:0-22:0', u'Tuesday 7:0-22:0', u'Wednesday 7:0-22:0', u'Thursday 7:0-22:0', u'Friday 7:0-23:0', u'Saturday 7:0-23:0', u'Sunday 7:0-22:0'], is_open=1, latitude=36.157156, longitude=-115.1538305, name=u'Casa Don Juan  - Downtown', neighborhood=u'Downtown', postal_code=u'89104', review_count=654, stars=4.0, state=u'NV', type=u'business')]

# %%
categories_attributes = business.select(["business_id", "categories"])

# %% [markdown]
# minDF=1: 1191
#
# minDF=10: 896
#
# minDF=100:473

# %%
word2vec = Word2Vec(vectorSize=200, minCount=10, inputCol="categories", outputCol="word2vec_categories")
word2vec_model = word2vec.fit(categories_attributes)
categories_word2vec = word2vec_model.transform(categories_attributes)

# %%
pca = PCA(k=100, inputCol="word2vec_categories", outputCol="pca_word2vec")
pca_model = pca.fit(categories_word2vec)
pca_word2vec_transformed = pca_model.transform(categories_word2vec)

gmm = GaussianMixture(k=10, featuresCol="pca_word2vec", predictionCol="cluster_num_pred", probabilityCol="pred_probability")
gmm_model = gmm.fit(pca_word2vec_transformed)
summary = gmm_model.summary
# Out:
# Exception AttributeError: "'PCA' object has no attribute '_java_obj'" in
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-b096cfbb2647> in <module>()
#       1 pca = PCA(k=100, inputCol="word2vec_categories", outputCol="pca_word2vec")
#       2 pca_model = pca.fit(categories_word2vec)
# ----> 3 pca_word2vec_transformed = pca_model.tranform(categories_word2vec)
#       4
#       5 gmm = GaussianMixture(k=10, featuresCol="pca_word2vec", predictionCol="cluster_num_pred", probabilityCol="pred_probability")
#
# AttributeError: 'PCAModel' object has no attribute 'tranform'

# %%
kmeans = KMeans(k=100, featuresCol="word2vec_categories", predictionCol="cluster_num_pred")
kmeans_model = kmeans.fit(categories_word2vec)
summary = kmeans_model.summary

print(summary.clusterSizes)
# print(kmeans_model.clusterCenters())
# Out:
# [767, 861, 301, 915, 195, 1148, 745, 409, 715, 813, 963, 1413, 1344, 866, 470, 802, 360, 555, 1401, 612, 359, 1155, 482, 276, 261, 247, 960, 1118, 1361, 563, 347, 420, 916, 427, 657, 652, 1001, 73, 316, 107, 576, 571, 758, 694, 1804, 570, 661, 774, 630, 354, 369, 273, 469, 364, 790, 657, 354, 424, 199, 1328, 1010, 837, 607, 985, 171, 379, 788, 554, 190, 376, 365, 1210, 1012, 769, 543, 616, 540, 320, 167, 1134, 87, 311, 307, 941, 969, 559, 1071, 538, 45, 527, 564, 427, 864, 276, 931, 598, 515, 244, 281, 504]

# %%
top_clusters_cats = [(x.argsort()[-3:][::-1], x[x.argsort()[-3:][::-1]]) for x in kmeans_model.clusterCenters()]
top_clusters_cats
# sorted([[(cv_model.vocabulary[elem[0]], elem[1]) for elem in zip(arr, vals)] for (arr, vals) in top_clusters_cats])
# Out:
# [(array([191, 184,  58]), array([ 0.348293  ,  0.30422422,  0.30206075])),
#  (array([ 42, 128, 131]), array([ 0.47944322,  0.39214722,  0.37816715])),
#  (array([ 11,  84, 110]), array([ 0.2963783 ,  0.29253959,  0.26505199])),
#  (array([174, 121,  42]), array([ 0.52530858,  0.50611063,  0.49817832])),
#  (array([ 81, 115, 168]), array([ 0.39015668,  0.34501581,  0.34499954])),
#  (array([174, 121,  42]), array([ 0.52604959,  0.49084959,  0.4892654 ])),
#  (array([ 42, 159, 186]), array([ 0.55428631,  0.49919414,  0.46790695])),
#  (array([50, 77, 62]), array([ 0.34942274,  0.33545212,  0.29159501])),
#  (array([ 63, 178, 123]), array([ 0.74259543,  0.60600426,  0.56419508])),
#  (array([119,  52,  91]), array([ 0.45927605,  0.44649998,  0.44099792])),
#  (array([109, 110,  21]), array([ 0.32971281,  0.30504707,  0.29429039])),
#  (array([163,  81,  91]), array([ 0.53365966,  0.46980108,  0.44237741])),
#  (array([105,  81,  30]), array([ 0.44628767,  0.41482998,  0.37823561])),
#  (array([ 21, 184, 187]), array([ 0.26100178,  0.24841077,  0.23596997])),
#  (array([158, 115, 177]), array([ 0.33867724,  0.32112137,  0.31621215])),
#  (array([163,  91,  81]), array([ 0.55306117,  0.48869512,  0.48156526])),
#  (array([ 81, 105,  57]), array([ 0.45625243,  0.37443763,  0.33963146])),
#  (array([ 42, 151, 128]), array([ 0.57305123,  0.44334618,  0.43712031])),
#  (array([50, 77, 62]), array([ 0.29122493,  0.28504028,  0.26383019])),
#  (array([ 81,   7, 105]), array([ 0.46198589,  0.36786697,  0.35029637])),
#  (array([ 81, 116,  91]), array([ 0.4071383 ,  0.33238534,  0.30980532])),
#  (array([ 42, 159, 186]), array([ 0.59936553,  0.48704829,  0.3993282 ])),
#  (array([151,  81,  17]), array([ 0.24350163,  0.23569123,  0.21908644])),
#  (array([ 91,  81, 194]), array([ 0.29545013,  0.26234033,  0.24499161])),
#  (array([115, 109,  55]), array([ 0.36131098,  0.32663445,  0.31214431])),
#  (array([105,  57,  81]), array([ 0.4015462 ,  0.39835672,  0.33856926])),
#  (array([ 81, 119,  91]), array([ 0.38373368,  0.34204233,  0.32193352])),
#  (array([191,  58,  39]), array([ 0.36325108,  0.32108316,  0.31118174])),
#  (array([ 84, 170,  11]), array([ 0.3240136 ,  0.29030281,  0.28206551])),
#  (array([ 81, 105,  57]), array([ 0.45203865,  0.33077121,  0.31849478])),
#  (array([ 81,  42, 105]), array([ 0.40353617,  0.30705857,  0.28435811])),
#  (array([ 62, 194,  50]), array([ 0.24328415,  0.23850519,  0.21748927])),
#  (array([ 11,  84, 114]), array([ 0.34895517,  0.33031204,  0.3002289 ])),
#  (array([115, 110, 158]), array([ 0.32426597,  0.28988239,  0.28587286])),
#  (array([ 94, 131,   5]), array([ 0.33586458,  0.33442106,  0.29477198])),
#  (array([194,   5, 131]), array([ 0.39422462,  0.34594206,  0.29910411])),
#  (array([ 81, 168, 115]), array([ 0.38341663,  0.36411441,  0.3617615 ])),
#  (array([ 63, 178, 189]), array([ 0.50079601,  0.42804706,  0.36920499])),
#  (array([ 81, 194, 105]), array([ 0.34886982,  0.33916336,  0.3307299 ])),
#  (array([ 42, 151, 128]), array([ 0.51791999,  0.40921162,  0.38909058])),
#  (array([131, 194, 129]), array([ 0.30541137,  0.25892961,  0.21803861])),
#  (array([115,  84,  99]), array([ 0.25391608,  0.23975074,  0.21226421])),
#  (array([50, 77, 98]), array([ 0.40244241,  0.37794234,  0.33518355])),
#  (array([84, 99, 11]), array([ 0.32212147,  0.28689151,  0.27920802])),
#  (array([174, 121, 128]), array([ 0.55174758,  0.53570493,  0.50329392])),
#  (array([158, 177, 115]), array([ 0.3756023 ,  0.34800013,  0.34145379])),
#  (array([ 84,  11, 170]), array([ 0.36304785,  0.35682208,  0.32397612])),
#  (array([105, 194,   7]), array([ 0.32123078,  0.31204429,  0.28687107])),
#  (array([81, 25, 39]), array([ 0.4154695 ,  0.37534749,  0.33758006])),
#  (array([110,  11, 177]), array([ 0.37083331,  0.34667667,  0.32956668])),
#  (array([105,  42, 109]), array([ 0.40520312,  0.39428754,  0.2914044 ])),
#  (array([ 81,  91, 105]), array([ 0.33879121,  0.28022722,  0.27423573])),
#  (array([194, 105,  81]), array([ 0.21815183,  0.2025154 ,  0.1758142 ])),
#  (array([194,   0,  42]), array([ 0.57234165,  0.53723518,  0.45599673])),
#  (array([115, 192,  84]), array([ 0.31509433,  0.30154453,  0.2862913 ])),
#  (array([ 52, 178, 119]), array([ 0.56521343,  0.55977547,  0.48487833])),
#  (array([191,  58, 113]), array([ 0.31873285,  0.30370793,  0.26738327])),
#  (array([62, 58, 77]), array([ 0.24426438,  0.22215621,  0.21969747])),
#  (array([ 42, 159, 105]), array([ 0.62384108,  0.45718696,  0.39751086])),
#  (array([ 11,  84, 170]), array([ 0.41205257,  0.40958674,  0.30728777])),
#  (array([ 11,  84, 110]), array([ 0.24146124,  0.22913816,  0.22278945])),
#  (array([ 55, 115,  58]), array([ 0.26911518,  0.2654225 ,  0.25168804])),
#  (array([115,  55, 158]), array([ 0.27910338,  0.27710793,  0.26346942])),
#  (array([ 21, 115,  84]), array([ 0.28302998,  0.27956944,  0.26667557])),
#  (array([ 42, 159, 151]), array([ 0.43882357,  0.33579394,  0.27116657])),
#  (array([ 11, 110, 109]), array([ 0.32090718,  0.28967969,  0.26665402])),
#  (array([ 11, 110, 109]), array([ 0.2642587 ,  0.26354158,  0.25706615])),
#  (array([184,  58, 115]), array([ 0.30452077,  0.30293163,  0.2416487 ])),
#  (array([ 57, 105, 131]), array([ 0.31914092,  0.29528862,  0.27324848])),
#  (array([115, 184, 110]), array([ 0.24509724,  0.23640378,  0.23023194])),
#  (array([105,  42, 183]), array([ 0.3378088 ,  0.32859308,  0.31934654])),
#  (array([110,  84,  21]), array([ 0.27223621,  0.26502742,  0.26428372])),
#  (array([191, 184, 113]), array([ 0.37233397,  0.34697377,  0.2900669 ])),
#  (array([84, 21,  2]), array([ 0.32527151,  0.31333304,  0.29808854])),
#  (array([ 58, 184,  84]), array([ 0.23402254,  0.23217639,  0.22159355])),
#  (array([ 21,  84, 115]), array([ 0.30913728,  0.30109091,  0.27439968])),
#  (array([ 50,  77, 177]), array([ 0.29974627,  0.28235349,  0.24665665])),
#  (array([151,  42, 105]), array([ 0.37962183,  0.37137684,  0.35085896])),
#  (array([ 81, 105,  57]), array([ 0.39695202,  0.29603415,  0.26997107])),
#  (array([77,  0, 50]), array([ 0.33066149,  0.30344684,  0.28987045])),
#  (array([ 96,  70, 186]), array([ 0.25870352,  0.25353257,  0.23927882])),
#  (array([ 63, 194, 178]), array([ 0.77465063,  0.59170402,  0.58470133])),
#  (array([184, 191,  62]), array([ 0.20608137,  0.19214463,  0.1772342 ])),
#  (array([50, 77, 62]), array([ 0.29450789,  0.292329  ,  0.26927938])),
#  (array([ 58, 184, 191]), array([ 0.39679005,  0.34913917,  0.29404528])),
#  (array([62, 77, 58]), array([ 0.26515102,  0.26000342,  0.25434888])),
#  (array([191, 184,  62]), array([ 0.28846644,  0.25042963,  0.24249972])),
#  (array([84, 21,  2]), array([ 0.25131912,  0.24430866,  0.23580096])),
#  (array([ 63, 194, 178]), array([ 0.36687588,  0.32208298,  0.29298218])),
#  (array([184,  58, 191]), array([ 0.2769789 ,  0.26889237,  0.24515589])),
#  (array([110, 184,  99]), array([ 0.28421888,  0.27931419,  0.27190571])),
#  (array([ 58,  30, 105]), array([ 0.2884098 ,  0.28027121,  0.24881831])),
#  (array([ 84, 170,  11]), array([ 0.32987246,  0.29272065,  0.27825067])),
#  (array([84, 11, 99]), array([ 0.27850365,  0.27287563,  0.26781629])),
#  (array([115,  11, 110]), array([ 0.35027792,  0.32784135,  0.30528134])),
#  (array([110,  11,  55]), array([ 0.29737914,  0.29542822,  0.29436838])),
#  (array([ 77, 109,  11]), array([ 0.22633459,  0.22530006,  0.22500039])),
#  (array([ 42,  81, 151]), array([ 0.28997282,  0.26780491,  0.23425114])),
#  (array([ 30, 105,  19]), array([ 0.42971916,  0.42608741,  0.37402653])),
#  (array([  0,  69, 194]), array([ 0.32014531,  0.30706552,  0.30455369]))]

# %%
cv = CountVectorizer(inputCol="categories", outputCol="category_count", minDF=10)
cv_model = cv.fit(categories_attributes)
# pipeline = Pipeline(stages=[cv])
# model = pipeline.fit(categories_attributes.limit(10))

categories_cv = cv_model.transform(categories_attributes)
categories_cv.show()

print(len(cv_model.vocabulary))
sorted(cv_model.vocabulary)
# Out:
# +--------------------+--------------------+--------------------+
# |         business_id|          categories|      category_count|
# +--------------------+--------------------+--------------------+
# |Eg9ZRsV5t64bWkK1N...|[Automotive, Auto...|(711,[12,28],[1.0...|
# |iyr2-mlj0oz04ADOO...|[Restaurants, Ame...|(711,[0,6,17,32],...|
# |MX5uyDRTey35fiGgR...|[Paint & Sip, Eve...|(711,[3,7,22,109,...|
# |GPGeSCvdPT_2La3Xz...|[Garage Door Serv...|(711,[8,341],[1.0...|
# |js21hDzpLZNkwWHwD...|[Shipping Centers...|(711,[20,191,207,...|
# |tryuF3QW5he0cUmd1...|[Gastropubs, Pubs...|(711,[0,2,4,35,11...|
# |_-u3js_j6WHkRZ416...|[Restaurants, Fre...|(711,[0,16,36,81,...|
# |SsJAn_JvZC4cbAg_e...|[American (Tradit...|(711,[0,6,19,83],...|
# |_yMMBQXcUQ1XtHQVa...|[Medical Centers,...|(711,[9,43,124,14...|
# |j7Gj8RjIVFotp3SfV...|    [Food, Bakeries]|(711,[1,31],[1.0,...|
# |301_dHmNWl6qxaTLD...|[Shopping, Fashio...|(711,[3,27,77,97,...|
# |dEh3Su-0GWDSQZYRl...|[Farmers Market, ...|(711,[1,251],[1.0...|
# |RKgDsDhUJhjtmL-6I...|[Financial Servic...|(711,[20,63,129,1...|
# |kQhgCtQ5jKKr2EldM...|[Pets, Pet Boardi...|(711,[41,64,92,99...|
# |40B7HIv74ZqU9tBxb...|[American (Tradit...|(711,[0,6,19],[1....|
# |x3-d_7Bgj4sYVks1x...|[Szechuan, Chines...|(711,[0,24,45,66,...|
# |fY0Dpw5a3i1CMjMuT...|[Middle Eastern, ...|(711,[0,54,86,290...|
# |j32eLTYoQef2ehvUb...|[Food, Bakeries, ...|(711,[1,31,33],[1...|
# |PSRE_EDOniELkQ4_o...|[Fashion, Shoppin...|(711,[3,27,91,161...|
# |D_s16LOzlDkLwa4S8...|[American (Tradit...|(711,[0,6,32,36],...|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# 711
# [u'ATV Rentals/Tours',
#  u'Acai Bowls',
#  u'Accessories',
#  u'Accountants',
#  u'Active Life',
#  u'Acupuncture',
#  u'Adult',
#  u'Adult Education',
#  u'Adult Entertainment',
#  u'Advertising',
#  u'Afghan',
#  u'African',
#  u'Air Duct Cleaning',
#  u'Airlines',
#  u'Airport Lounges',
#  u'Airport Shuttles',
#  u'Airports',
#  u'Allergists',
#  u'Amateur Sports Teams',
#  u'American (New)',
#  u'American (Traditional)',
#  u'Amusement Parks',
#  u'Animal Shelters',
#  u'Antiques',
#  u'Apartments',
#  u'Appliances',
#  u'Appliances & Repair',
#  u'Appraisal Services',
#  u'Aquarium Services',
#  u'Aquariums',
#  u'Arabian',
#  u'Arcades',
#  u'Archery',
#  u'Argentine',
#  u'Art Classes',
#  u'Art Galleries',
#  u'Art Museums',
#  u'Art Schools',
#  u'Art Supplies',
#  u'Arts & Crafts',
#  u'Arts & Entertainment',
#  u'Asian Fusion',
#  u'Auction Houses',
#  u'Auto Customization',
#  u'Auto Detailing',
#  u'Auto Glass Services',
#  u'Auto Insurance',
#  u'Auto Loan Providers',
#  u'Auto Parts & Supplies',
#  u'Auto Repair',
#  u'Automotive',
#  u'Baby Gear & Furniture',
#  u'Bagels',
#  u'Bakeries',
#  u'Bankruptcy Law',
#  u'Banks & Credit Unions',
#  u'Barbeque',
#  u'Barbers',
#  u'Barre Classes',
#  u'Bars',
#  u'Basque',
#  u'Beaches',
#  u'Beauty & Spas',
#  u'Bed & Breakfast',
#  u'Beer',
#  u'Beer Bar',
#  u'Beer Garden',
#  u'Beer Gardens',
#  u'Belgian',
#  u'Bespoke Clothing',
#  u'Bike Rentals',
#  u'Bike Repair/Maintenance',
#  u'Bikes',
#  u'Bistros',
#  u'Blow Dry/Out Services',
#  u'Boat Charters',
#  u'Boat Repair',
#  u'Boating',
#  u'Body Shops',
#  u'Books',
#  u'Bookstores',
#  u'Boot Camps',
#  u'Botanical Gardens',
#  u'Bowling',
#  u'Boxing',
#  u'Brasseries',
#  u'Brazilian',
#  u'Breakfast & Brunch',
#  u'Breweries',
#  u'Brewing Supplies',
#  u'Bridal',
#  u'British',
#  u'Bubble Tea',
#  u'Buffets',
#  u'Building Supplies',
#  u'Burgers',
#  u'Bus Tours',
#  u'Buses',
#  u'Butcher',
#  u'CPR Classes',
#  u'Cabaret',
#  u'Cabinetry',
#  u'Cafes',
#  u'Cafeteria',
#  u'Cajun/Creole',
#  u'Cambodian',
#  u'Campgrounds',
#  u'Canadian (New)',
#  u'Candy Stores',
#  u'Cannabis Clinics',
#  u'Cantonese',
#  u'Car Dealers',
#  u'Car Rental',
#  u'Car Stereo Installation',
#  u'Car Wash',
#  u'Cardiologists',
#  u'Cards & Stationery',
#  u'Caribbean',
#  u'Carpet Cleaning',
#  u'Carpet Installation',
#  u'Carpeting',
#  u'Casinos',
#  u'Caterers',
#  u'Challenge Courses',
#  u'Champagne Bars',
#  u'Cheese Shops',
#  u'Cheesesteaks',
#  u'Chicken Shop',
#  u'Chicken Wings',
#  u'Child Care & Day Care',
#  u"Children's Clothing",
#  u'Chinese',
#  u'Chiropractors',
#  u'Chocolatiers & Shops',
#  u'Christmas Trees',
#  u'Churches',
#  u'Cinema',
#  u'Climbing',
#  u'Cocktail Bars',
#  u'Coffee & Tea',
#  u'Coffee Roasteries',
#  u'Coffeeshops',
#  u'Colleges & Universities',
#  u'Colombian',
#  u'Comedy Clubs',
#  u'Comfort Food',
#  u'Comic Books',
#  u'Commercial Real Estate',
#  u'Community Service/Non-Profit',
#  u'Computers',
#  u'Contractors',
#  u'Convenience Stores',
#  u'Cooking Classes',
#  u'Cooking Schools',
#  u'Cosmetic Dentists',
#  u'Cosmetic Surgeons',
#  u'Cosmetics & Beauty Supply',
#  u'Cosmetology Schools',
#  u'Costumes',
#  u'Counseling & Mental Health',
#  u'Country Clubs',
#  u'Country Dance Halls',
#  u'Couriers & Delivery Services',
#  u'Creperies',
#  u'Criminal Defense Law',
#  u'Cuban',
#  u'Cupcakes',
#  u'Custom Cakes',
#  u'Customized Merchandise',
#  u'Cycling Classes',
#  u'DJs',
#  u'DUI Law',
#  u'Damage Restoration',
#  u'Dance Clubs',
#  u'Dance Schools',
#  u'Dance Studios',
#  u'Data Recovery',
#  u'Day Spas',
#  u'Delicatessen',
#  u'Delis',
#  u'Dentists',
#  u'Department Stores',
#  u'Departments of Motor Vehicles',
#  u'Dermatologists',
#  u'Desserts',
#  u'Diagnostic Imaging',
#  u'Diagnostic Services',
#  u'Dim Sum',
#  u'Diners',
#  u'Discount Store',
#  u'Distilleries',
#  u'Dive Bars',
#  u'Diving',
#  u'Divorce & Family Law',
#  u'Do-It-Yourself Food',
#  u'Doctors',
#  u'Dog Parks',
#  u'Dog Walkers',
#  u'Donuts',
#  u'Door Sales/Installation',
#  u'Doulas',
#  u'Driving Schools',
#  u'Drugstores',
#  u'Dry Cleaning',
#  u'Dry Cleaning & Laundry',
#  u'Drywall Installation & Repair',
#  u'Ear Nose & Throat',
#  u'Education',
#  u'Educational Services',
#  u'Electricians',
#  u'Electronics',
#  u'Electronics Repair',
#  u'Elementary Schools',
#  u'Embroidery & Crochet',
#  u'Emergency Pet Hospital',
#  u'Emergency Rooms',
#  u'Employment Agencies',
#  u'Endocrinologists',
#  u'Endodontists',
#  u'Escape Games',
#  u'Estate Planning Law',
#  u'Ethiopian',
#  u'Ethnic Food',
#  u'Event Photography',
#  u'Event Planning & Services',
#  u'Eyebrow Services',
#  u'Eyelash Service',
#  u'Eyewear & Opticians',
#  u'Fabric Stores',
#  u'Falafel',
#  u'Family Practice',
#  u'Farmers Market',
#  u'Fashion',
#  u'Fast Food',
#  u'Fences & Gates',
#  u'Fertility',
#  u'Festivals',
#  u'Filipino',
#  u'Financial Advising',
#  u'Financial Services',
#  u'Fish & Chips',
#  u'Fitness & Instruction',
#  u'Flea Markets',
#  u'Flooring',
#  u'Florists',
#  u'Flowers & Gifts',
#  u'Fondue',
#  u'Food',
#  u'Food Court',
#  u'Food Delivery Services',
#  u'Food Stands',
#  u'Food Trucks',
#  u'Formal Wear',
#  u'Framing',
#  u'French',
#  u'Fruits & Veggies',
#  u'Funeral Services & Cemeteries',
#  u'Furniture Reupholstery',
#  u'Furniture Stores',
#  u'Garage Door Services',
#  u'Gardeners',
#  u'Gas & Service Stations',
#  u'Gastropubs',
#  u'Gay Bars',
#  u'Gelato',
#  u'General Dentistry',
#  u'General Litigation',
#  u'German',
#  u'Gift Shops',
#  u'Glass & Mirrors',
#  u'Gluten-Free',
#  u'Go Karts',
#  u'Gold Buyers',
#  u'Golf',
#  u'Golf Equipment',
#  u'Graphic Design',
#  u'Greek',
#  u'Grocery',
#  u'Guitar Stores',
#  u'Gun/Rifle Ranges',
#  u'Guns & Ammo',
#  u'Gymnastics',
#  u'Gyms',
#  u'Hair Extensions',
#  u'Hair Loss Centers',
#  u'Hair Removal',
#  u'Hair Salons',
#  u'Hair Stylists',
#  u'Halal',
#  u'Handyman',
#  u'Hardware Stores',
#  u'Haunted Houses',
#  u'Hawaiian',
#  u'Head Shops',
#  u'Health & Medical',
#  u'Health Markets',
#  u'Health Retreats',
#  u'Heating & Air Conditioning/HVAC',
#  u'Henna Artists',
#  u'Herbs & Spices',
#  u'Hiking',
#  u'Himalayan/Nepalese',
#  u'Historical Tours',
#  u'Hobby Shops',
#  u'Home & Garden',
#  u'Home & Rental Insurance',
#  u'Home Automation',
#  u'Home Cleaning',
#  u'Home Decor',
#  u'Home Health Care',
#  u'Home Inspectors',
#  u'Home Organization',
#  u'Home Services',
#  u'Home Staging',
#  u'Home Theatre Installation',
#  u'Home Window Tinting',
#  u'Hookah Bars',
#  u'Horseback Riding',
#  u'Hospitals',
#  u'Hostels',
#  u'Hot Dogs',
#  u'Hot Pot',
#  u'Hot Tub & Pool',
#  u'Hotels',
#  u'Hotels & Travel',
#  u'Hungarian',
#  u'IT Services & Computer Repair',
#  u'Ice Cream & Frozen Yogurt',
#  u'Imported Food',
#  u'Indian',
#  u'Indonesian',
#  u'Insurance',
#  u'Interior Design',
#  u'Internal Medicine',
#  u'International',
#  u'International Grocery',
#  u'Internet Cafes',
#  u'Internet Service Providers',
#  u'Interval Training Gyms',
#  u'Investing',
#  u'Irish',
#  u'Irish Pub',
#  u'Irrigation',
#  u'Italian',
#  u'Japanese',
#  u'Jazz & Blues',
#  u'Jewelry',
#  u'Jewelry Repair',
#  u'Juice Bars & Smoothies',
#  u'Junk Removal & Hauling',
#  u'Karaoke',
#  u'Kebab',
#  u'Keys & Locksmiths',
#  u'Kids Activities',
#  u'Kitchen & Bath',
#  u'Knitting Supplies',
#  u'Korean',
#  u'Kosher',
#  u'Laboratory Testing',
#  u'Lactation Services',
#  u'Lakes',
#  u'Landmarks & Historical Buildings',
#  u'Landscape Architects',
#  u'Landscaping',
#  u'Laotian',
#  u'Laser Eye Surgery/Lasik',
#  u'Laser Hair Removal',
#  u'Laser Tag',
#  u'Latin American',
#  u'Laundromat',
#  u'Laundry Services',
#  u'Lawyers',
#  u'Leather Goods',
#  u'Lebanese',
#  u'Legal Services',
#  u'Leisure Centers',
#  u'Libraries',
#  u'Life Coach',
#  u'Life Insurance',
#  u'Lighting Fixtures & Equipment',
#  u'Limos',
#  u'Lingerie',
#  u'Live/Raw Food',
#  u'Local Fish Stores',
#  u'Local Flavor',
#  u'Local Services',
#  u'Lounges',
#  u'Luggage',
#  u'Macarons',
#  u'Magicians',
#  u'Mags',
#  u'Mailbox Centers',
#  u'Makeup Artists',
#  u'Malaysian',
#  u'Marketing',
#  u'Martial Arts',
#  u'Masonry/Concrete',
#  u'Mass Media',
#  u'Massage',
#  u'Massage Schools',
#  u'Massage Therapy',
#  u'Maternity Wear',
#  u'Mattresses',
#  u'Meat Shops',
#  u'Medical Centers',
#  u'Medical Spas',
#  u'Medical Supplies',
#  u'Meditation Centers',
#  u'Mediterranean',
#  u"Men's Clothing",
#  u"Men's Hair Salons",
#  u'Mexican',
#  u'Middle Eastern',
#  u'Midwives',
#  u'Mini Golf',
#  u'Mobile Dent Repair',
#  u'Mobile Phone Accessories',
#  u'Mobile Phone Repair',
#  u'Mobile Phones',
#  u'Modern European',
#  u'Mongolian',
#  u'Moroccan',
#  u'Mortgage Brokers',
#  u'Motorcycle Dealers',
#  u'Motorcycle Gear',
#  u'Motorcycle Rental',
#  u'Motorcycle Repair',
#  u'Mountain Biking',
#  u'Movers',
#  u'Museums',
#  u'Music & DVDs',
#  u'Music & Video',
#  u'Music Venues',
#  u'Musical Instrument Services',
#  u'Musical Instruments & Teachers',
#  u'Nail Salons',
#  u'Nail Technicians',
#  u'Naturopathic/Holistic',
#  u'Neurologist',
#  u'New Mexican Cuisine',
#  u'Newspapers & Magazines',
#  u'Nightlife',
#  u'Noodles',
#  u'Notaries',
#  u'Nurseries & Gardening',
#  u'Nutritionists',
#  u'Obstetricians & Gynecologists',
#  u'Occupational Therapy',
#  u'Office Cleaning',
#  u'Office Equipment',
#  u'Officiants',
#  u'Oil Change Stations',
#  u'Opera & Ballet',
#  u'Ophthalmologists',
#  u'Optometrists',
#  u'Oral Surgeons',
#  u'Organic Stores',
#  u'Orthodontists',
#  u'Orthopedists',
#  u'Outdoor Gear',
#  u'Outlet Stores',
#  u'Packing Services',
#  u'Pain Management',
#  u'Paint & Sip',
#  u'Paint Stores',
#  u'Paint-Your-Own Pottery',
#  u'Paintball',
#  u'Painters',
#  u'Pakistani',
#  u'Parking',
#  u'Parks',
#  u'Party & Event Planning',
#  u'Party Bus Rentals',
#  u'Party Equipment Rentals',
#  u'Party Supplies',
#  u'Pasta Shops',
#  u'Patisserie/Cake Shop',
#  u'Pawn Shops',
#  u'Payroll Services',
#  u'Pediatric Dentists',
#  u'Pediatricians',
#  u'Performing Arts',
#  u'Periodontists',
#  u'Permanent Makeup',
#  u'Persian/Iranian',
#  u'Personal Chefs',
#  u'Personal Injury Law',
#  u'Personal Shopping',
#  u'Peruvian',
#  u'Pest Control',
#  u'Pet Adoption',
#  u'Pet Boarding/Pet Sitting',
#  u'Pet Groomers',
#  u'Pet Services',
#  u'Pet Stores',
#  u'Pet Training',
#  u'Pets',
#  u'Photo Booth Rentals',
#  u'Photographers',
#  u'Photography Stores & Services',
#  u'Physical Therapy',
#  u'Piano Bars',
#  u'Piercing',
#  u'Pilates',
#  u'Pizza',
#  u'Playgrounds',
#  u'Plumbing',
#  u'Plus Size Fashion',
#  u'Podiatrists',
#  u'Poke',
#  u'Polish',
#  u'Pool & Hot Tub Service',
#  u'Pool Cleaners',
#  u'Pool Halls',
#  u'Popcorn Shops',
#  u'Portuguese',
#  u'Post Offices',
#  u'Poutineries',
#  u'Preschools',
#  u'Pressure Washers',
#  u'Pretzels',
#  u'Print Media',
#  u'Printing Services',
#  u'Professional Services',
#  u'Professional Sports Teams',
#  u'Property Management',
#  u'Psychics & Astrologers',
#  u'Public Services & Government',
#  u'Public Transportation',
#  u'Pubs',
#  u'Puerto Rican',
#  u'RV Dealers',
#  u'RV Parks',
#  u'RV Rental',
#  u'RV Repair',
#  u'Race Tracks',
#  u'Radio Stations',
#  u'Radiologists',
#  u'Rafting/Kayaking',
#  u'Ramen',
#  u'Real Estate',
#  u'Real Estate Agents',
#  u'Real Estate Services',
#  u'Recreation Centers',
#  u'Recycling Center',
#  u'Refinishing Services',
#  u'Reflexology',
#  u'Registration Services',
#  u'Rehabilitation Center',
#  u'Reiki',
#  u'Religious Organizations',
#  u'Resorts',
#  u'Restaurants',
#  u'Roadside Assistance',
#  u'Rock Climbing',
#  u'Roofing',
#  u'Rugs',
#  u'Russian',
#  u'Salad',
#  u'Salvadoran',
#  u'Sandwiches',
#  u'Scandinavian',
#  u'Scottish',
#  u'Screen Printing',
#  u'Screen Printing/T-Shirt Printing',
#  u'Scuba Diving',
#  u'Seafood',
#  u'Seafood Markets',
#  u'Security Services',
#  u'Security Systems',
#  u'Self Storage',
#  u'Septic Services',
#  u'Session Photography',
#  u'Sewing & Alterations',
#  u'Shades & Blinds',
#  u'Shaved Ice',
#  u'Shipping Centers',
#  u'Shoe Repair',
#  u'Shoe Stores',
#  u'Shopping',
#  u'Shopping Centers',
#  u'Shutters',
#  u'Signmaking',
#  u'Singaporean',
#  u'Skate Parks',
#  u'Skating Rinks',
#  u'Skin Care',
#  u'Smog Check Stations',
#  u'Smokehouse',
#  u'Soccer',
#  u'Social Clubs',
#  u'Solar Installation',
#  u'Soul Food',
#  u'Soup',
#  u'South African',
#  u'Southern',
#  u'Souvenir Shops',
#  u'Spanish',
#  u'Special Education',
#  u'Specialty Food',
#  u'Specialty Schools',
#  u'Sporting Goods',
#  u'Sports Bars',
#  u'Sports Clubs',
#  u'Sports Medicine',
#  u'Sports Wear',
#  u'Spray Tanning',
#  u'Stadiums & Arenas',
#  u'Steakhouses',
#  u'Street Vendors',
#  u'Sugaring',
#  u'Summer Camps',
#  u'Surgeons',
#  u'Sushi Bars',
#  u'Swabian',
#  u'Swimming Lessons/Schools',
#  u'Swimming Pools',
#  u'Swimwear',
#  u'Szechuan',
#  u'Tabletop Games',
#  u'Tacos',
#  u'Taiwanese',
#  u'Tanning',
#  u'Tanning Beds',
#  u'Tapas Bars',
#  u'Tapas/Small Plates',
#  u'Tattoo',
#  u'Tattoo Removal',
#  u'Tax Services',
#  u'Taxis',
#  u'Tea Rooms',
#  u'Teeth Whitening',
#  u'Telecommunications',
#  u'Television Service Providers',
#  u'Television Stations',
#  u'Tennis',
#  u'Teppanyaki',
#  u'Tex-Mex',
#  u'Thai',
#  u'Threading Services',
#  u'Thrift Stores',
#  u'Ticket Sales',
#  u'Tiki Bars',
#  u'Tiling',
#  u'Tires',
#  u'Tobacco Shops',
#  u'Tours',
#  u'Towing',
#  u'Toy Stores',
#  u'Traditional Chinese Medicine',
#  u'Train Stations',
#  u'Trainers',
#  u'Trampoline Parks',
#  u'Transmission Repair',
#  u'Transportation',
#  u'Travel Services',
#  u'Tree Services',
#  u'Truck Rental',
#  u'Turkish',
#  u'Ukrainian',
#  u'Uniforms',
#  u'University Housing',
#  u'Urgent Care',
#  u'Used',
#  u'Used Car Dealers',
#  u'Utilities',
#  u'Vacation Rentals',
#  u'Vape Shops',
#  u'Vegan',
#  u'Vegetarian',
#  u'Vehicle Wraps',
#  u'Venezuelan',
#  u'Venues & Event Spaces',
#  u'Veterinarians',
#  u'Video Game Stores',
#  u'Video/Film Production',
#  u'Videographers',
#  u'Videos & Video Game Rental',
#  u'Vietnamese',
#  u'Vintage & Consignment',
#  u'Vinyl Records',
#  u'Vitamins & Supplements',
#  u'Vocational & Technical School',
#  u'Waffles',
#  u'Walk-in Clinics',
#  u'Watch Repair',
#  u'Watches',
#  u'Water Delivery',
#  u'Water Heater Installation/Repair',
#  u'Water Purification Services',
#  u'Waxing',
#  u'Web Design',
#  u'Wedding Chapels',
#  u'Wedding Planning',
#  u'Weight Loss Centers',
#  u'Wheel & Rim Repair',
#  u'Whiskey Bars',
#  u'Wholesale Stores',
#  u'Wholesalers',
#  u'Wigs',
#  u'Window Washing',
#  u'Windows Installation',
#  u'Windshield Installation & Repair',
#  u'Wine & Spirits',
#  u'Wine Bars',
#  u'Wine Tasting Room',
#  u'Wineries',
#  u"Women's Clothing",
#  u'Yelp Events',
#  u'Yoga',
#  u'Zoos']

# %%
categories_cv.printSchema()
# Out:
# root
#  |-- business_id: string (nullable = true)
#  |-- categories: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- category_count: vector (nullable = true)

# %%
pca = PCA(k=100, inputCol="category_count", outputCol="pca_category_count")
pca_model = pca.fit(categories_cv)
pca_transformed = pca_model.transform(categories_cv)

gmm = GaussianMixture(k=10, featuresCol="pca_category_count", predictionCol="cluster_num_pred", probabilityCol="pred_probability")
gmm_model = gmm.fit(pca_transformed)
summary = gmm_model.summary

# %%
kmeans = KMeans(k=100, featuresCol="category_count", predictionCol="cluster_num_pred")
kmeans_model = kmeans.fit(categories_cv)
summary = kmeans_model.summary

print(summary.clusterSizes)
# print(kmeans_model.clusterCenters())
# Out:
# [1104, 522, 1197, 1600, 804, 572, 2958, 438, 309, 83, 1600, 2702, 615, 1576, 1353, 830, 533, 982, 945, 304, 1644, 448, 1363, 1018, 952, 349, 655, 279, 702, 280, 292, 1190, 978, 1655, 42, 453, 1343, 372, 528, 531, 236, 143, 117, 1455, 1090, 392, 271, 1156, 109, 817, 269, 410, 1116, 361, 973, 184, 642, 330, 431, 140, 640, 494, 221, 439, 174, 530, 511, 1037, 380, 103, 878, 258, 364, 27, 396, 244, 883, 81, 298, 430, 296, 469, 1636, 79, 210, 153, 114, 133, 98, 991, 280, 162, 729, 951, 144, 67, 402, 273, 441, 345]

# %%
top_clusters_cats = [(np.where(x > 0.9)[0], x[np.where(x > 0.9)]) for x in kmeans_model.clusterCenters()]
# print(top_clusters_cats)
sorted([[(cv_model.vocabulary[elem[0]], elem[1]) for elem in zip(arr, vals)] for (arr, vals) in top_clusters_cats])
# Out:
# [[],
#  [(u'Active Life', 1.0)],
#  [(u'Active Life', 1.0), (u'Fitness & Instruction', 1.0)],
#  [(u'Active Life', 1.0),
#   (u'Fitness & Instruction', 1.0),
#   (u'Gyms', 0.94436090225563918)],
#  [(u'Active Life', 1.0), (u'Parks', 1.0)],
#  [(u'Arts & Entertainment', 1.0), (u'Museums', 1.0)],
#  [(u'Arts & Entertainment', 1.0), (u'Psychics & Astrologers', 1.0)],
#  [(u'Automotive', 0.99999999999999989)],
#  [(u'Automotive', 0.99999999999999989), (u'Car Dealers', 0.99999999999999989)],
#  [(u'Automotive', 1.0)],
#  [(u'Beauty & Spas', 1.0)],
#  [(u'Beauty & Spas', 1.0)],
#  [(u'Beauty & Spas', 1.0), (u'Education', 1.0), (u'Specialty Schools', 1.0)],
#  [(u'Beauty & Spas', 1.0), (u'Hair Removal', 0.99806201550387597)],
#  [(u'Beauty & Spas', 1.0), (u'Hair Removal', 1.0)],
#  [(u'Beauty & Spas', 1.0), (u'Hair Salons', 1.0)],
#  [(u'Beauty & Spas', 1.0),
#   (u'Hair Salons', 1.0),
#   (u'Hair Stylists', 0.92789968652037613)],
#  [(u'Beauty & Spas', 1.0), (u'Massage', 0.95278246205733552)],
#  [(u'Education', 1.0)],
#  [(u'Event Planning & Services', 1.0)],
#  [(u'Event Planning & Services', 1.0), (u'Caterers', 1.0)],
#  [(u'Event Planning & Services', 1.0),
#   (u'Hotels & Travel', 1.0),
#   (u'Hotels', 0.99926470588235294)],
#  [(u'Financial Services', 1.0)],
#  [(u'Food', 1.0)],
#  [(u'Food', 1.0), (u'Coffee & Tea', 0.9838709677419355)],
#  [(u'Food', 1.0), (u'Donuts', 1.0)],
#  [(u'Food', 1.0), (u'Juice Bars & Smoothies', 1.0)],
#  [(u'Food', 1.0),
#   (u'Nightlife', 1.0),
#   (u'Bars', 0.92957746478873238),
#   (u'Breweries', 1.0)],
#  [(u'Food', 1.0),
#   (u'Nightlife', 1.0),
#   (u'Bars', 0.97607655502392343),
#   (u'Wine & Spirits', 1.0),
#   (u'Beer', 1.0)],
#  [(u'Food', 1.0),
#   (u'Shopping', 1.0),
#   (u'Beauty & Spas', 0.95180722891566272),
#   (u'Cosmetics & Beauty Supply', 0.95180722891566272),
#   (u'Drugstores', 0.95180722891566272),
#   (u'Convenience Stores', 0.97590361445783136)],
#  [(u'Food', 1.0), (u'Shopping', 1.0), (u'Grocery', 0.99585062240663902)],
#  [(u'Food', 1.0), (u'Specialty Food', 1.0)],
#  [(u'Food', 1.0), (u'Specialty Food', 1.0), (u'Meat Shops', 1.0)],
#  [(u'Food', 1.0), (u'Wine & Spirits', 1.0), (u'Beer', 1.0)],
#  [(u'Health & Medical', 1.0)],
#  [(u'Health & Medical', 1.0), (u'Dentists', 1.0)],
#  [(u'Health & Medical', 1.0), (u'Diagnostic Services', 1.0)],
#  [(u'Health & Medical', 1.0), (u'Optometrists', 0.99551569506726456)],
#  [(u'Home Services', 1.0)],
#  [(u'Home Services', 1.0)],
#  [(u'Home Services', 1.0)],
#  [(u'Home Services', 1.0),
#   (u'Local Services', 1.0),
#   (u'Movers', 0.97391304347826091)],
#  [(u'Home Services', 1.0), (u'Real Estate', 1.0)],
#  [(u'Home Services', 1.0), (u'Real Estate', 1.0), (u'Apartments', 1.0)],
#  [(u'Hotels & Travel', 1.0)],
#  [(u'Hotels & Travel', 1.0), (u'Transportation', 1.0)],
#  [(u'Local Services', 0.99999999999999989)],
#  [(u'Local Services', 1.0),
#   (u'IT Services & Computer Repair', 0.96057347670250892)],
#  [(u'Nightlife', 1.0)],
#  [(u'Nightlife', 1.0), (u'Bars', 1.0), (u'Hookah Bars', 1.0)],
#  [(u'Nightlife', 1.0), (u'Bars', 1.0), (u'Pubs', 1.0)],
#  [(u'Nightlife', 1.0), (u'Bars', 1.0), (u'Wine Bars', 1.0)],
#  [(u'Pets', 1.0)],
#  [(u'Restaurants', 0.99956331877729265),
#   (u'Nightlife', 1.0),
#   (u'Bars', 0.99825327510917028)],
#  [(u'Restaurants', 0.99999999999999989), (u'Chinese', 0.99999999999999989)],
#  [(u'Restaurants', 0.99999999999999989), (u'Mexican', 0.99999999999999989)],
#  [(u'Restaurants', 0.99999999999999989),
#   (u'Pizza', 0.99999999999999989),
#   (u'Italian', 0.99999999999999989)],
#  [(u'Restaurants', 1.0)],
#  [(u'Restaurants', 1.0)],
#  [(u'Restaurants', 1.0)],
#  [(u'Restaurants', 1.0)],
#  [(u'Restaurants', 1.0)],
#  [(u'Restaurants', 1.0), (u'American (New)', 1.0)],
#  [(u'Restaurants', 1.0), (u'American (Traditional)', 1.0)],
#  [(u'Restaurants', 1.0), (u'Asian Fusion', 1.0)],
#  [(u'Restaurants', 1.0), (u'Burgers', 1.0)],
#  [(u'Restaurants', 1.0), (u'Chinese', 1.0)],
#  [(u'Restaurants', 1.0),
#   (u'Event Planning & Services', 1.0),
#   (u'Caterers', 0.97222222222222221)],
#  [(u'Restaurants', 1.0), (u'Fast Food', 1.0)],
#  [(u'Restaurants', 1.0), (u'Food', 1.0)],
#  [(u'Restaurants', 1.0), (u'Food', 1.0), (u'American (Traditional)', 1.0)],
#  [(u'Restaurants', 1.0), (u'Food', 1.0), (u'Coffee & Tea', 1.0)],
#  [(u'Restaurants', 1.0), (u'Food', 1.0), (u'Desserts', 1.0)],
#  [(u'Restaurants', 1.0), (u'Food', 1.0), (u'Sandwiches', 1.0)],
#  [(u'Restaurants', 1.0), (u'Food', 1.0), (u'Sandwiches', 1.0)],
#  [(u'Restaurants', 1.0), (u'French', 1.0)],
#  [(u'Restaurants', 1.0), (u'Greek', 1.0)],
#  [(u'Restaurants', 1.0), (u'Indian', 1.0)],
#  [(u'Restaurants', 1.0), (u'Latin American', 1.0)],
#  [(u'Restaurants', 1.0), (u'Mexican', 1.0), (u'Seafood', 1.0)],
#  [(u'Restaurants', 1.0), (u'Nightlife', 1.0), (u'Bars', 0.99897119341563789)],
#  [(u'Restaurants', 1.0),
#   (u'Nightlife', 1.0),
#   (u'Bars', 1.0),
#   (u'Sports Bars', 1.0)],
#  [(u'Restaurants', 1.0), (u'Pizza', 1.0)],
#  [(u'Restaurants', 1.0), (u'Sandwiches', 1.0)],
#  [(u'Restaurants', 1.0), (u'Seafood', 1.0)],
#  [(u'Restaurants', 1.0), (u'Steakhouses', 1.0)],
#  [(u'Restaurants', 1.0), (u'Steakhouses', 1.0)],
#  [(u'Restaurants', 1.0), (u'Sushi Bars', 1.0)],
#  [(u'Restaurants', 1.0), (u'Vietnamese', 1.0)],
#  [(u'Shopping', 1.0)],
#  [(u'Shopping', 1.0)],
#  [(u'Shopping', 1.0),
#   (u'Beauty & Spas', 1.0),
#   (u'Cosmetics & Beauty Supply', 1.0)],
#  [(u'Shopping', 1.0), (u'Fashion', 1.0)],
#  [(u'Shopping', 1.0), (u'Fashion', 1.0), (u'Accessories', 1.0)],
#  [(u'Shopping', 1.0), (u'Flowers & Gifts', 1.0)],
#  [(u'Shopping', 1.0), (u'Home & Garden', 1.0)],
#  [(u'Shopping', 1.0),
#   (u'Home & Garden', 1.0),
#   (u'Furniture Stores', 0.97714285714285709)],
#  [(u'Shopping', 1.0),
#   (u'Home & Garden', 1.0),
#   (u'Home Decor', 0.97101449275362317)],
#  [(u'Shopping', 1.0),
#   (u'Home Services', 0.97482014388489213),
#   (u'Home & Garden', 0.98201438848920863)],
#  [(u'Shopping', 1.0), (u'Sporting Goods', 1.0)]]

# %%
exploded_cats = categories_attributes.select([col("business_id"), explode("categories").alias("category")])
categories = exploded_cats.groupby("category").count().where(col("count")>=10).select("category")
print(categories.count())
# Out:
# 711

# %%
# exploded_cats.head(10)
# overlapping_cats_pairs = (exploded_cats.alias("t1")
#                           .join(exploded_cats.alias("t2"), (col("t1.business_id") < col("t2.business_id")) & (col("t1.category") == col("t2.category")))
#                           .select(["t1.business_id", "t2.business_id"]).distinct()
#                          )
# overlapping_cats_pairs = (exploded_cats.alias("t1")
#                           .join(categories_attributes.alias("t2"), (col("t1.business_id") < col("t2.business_id")) & (expr("array_contains(categories, category)")))
#                           .select(["t1.business_id", "t2.business_id"]).distinct())

overlapping_cats_pairs = (categories_attributes.alias("t1")
                         .join(categories_attributes.alias("t2"), col("t1.business_id")<col("t2.business_id"))
                         .join(categories.alias("c"), expr("array_contains(t1.categories, c.category)") & expr("array_contains(t2.categories, c.category)"))
                         .select(["t1.business_id", "t2.business_id"])
                         .distinct()
                        )


overlapping_cats_pairs.head(20)

# %%
idf = IDF(minDocFreq=10, inputCol="category_count", outputCol="categories_idf")
idf_model = idf.fit(categories_cv)
# print(idf_model.idf)

categories_idf = idf_model.transform(categories_cv)
categories_idf.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+
# |         business_id|          categories|      category_count|      categories_idf|
# +--------------------+--------------------+--------------------+--------------------+
# |CYIQVaW41UoDDikFl...|[Arts & Entertain...|(896,[20,219],[1....|(896,[20,219],[3....|
# |9ezDpuzoOhkDgzfwM...|[Sandwiches, Rest...|(896,[0,15,16],[1...|(896,[0,15,16],[1...|
# |bOS7Iy2FOy1Nd3qPk...|[Mobile Phone Acc...|(896,[1,9,118,224...|(896,[1,9,118,224...|
# |LEASX4wn1U1TAmwQf...|[Arts & Entertain...|(896,[10,11,19,20...|(896,[10,11,19,20...|
# |GSOYOUQa5pY19EP3J...|[Chinese, Restaur...|(896,[0,27],[1.0,...|(896,[0,27],[1.08...|
# |TG6m1XuLFgbYRGo-4...|[Towing, Auto Rep...|(896,[1,8,20,22,7...|(896,[1,8,20,22,7...|
# |kXLz9O3vHAoxYVN4X...|[Nightlife, Adult...|(896,[3,5,18,30,2...|(896,[3,5,18,30,2...|
# |HKFOt7gx-WCPJhTNb...|[Education, Colle...|(896,[48,337],[1....|(896,[48,337],[4....|
# |gPuj_VV2Yzj-IhqSV...|[Nightlife, Wine ...|(896,[5,7,119],[1...|(896,[5,7,119],[2...|
# |7bFqnBRxT0rbexxsL...|[Jazz & Blues, Ar...|(896,[5,20,447],[...|(896,[5,20,447],[...|
# |PvtAsnMf-oeNmkvdw...|[Pizza, Restaurants]|(896,[0,15],[1.0,...|(896,[0,15],[1.08...|
# |LCL2-eg9k4lTZhZLD...|[Restaurants, Pizza]|(896,[0,15],[1.0,...|(896,[0,15],[1.08...|
# |HyzHidtQXC4JIULtS...|[Middle Eastern, ...|(896,[0,2,72,104,...|(896,[0,2,72,104,...|
# |n4q9ocOlUw6YqGl7o...|[Delis, Restauran...|(896,[0,16,26,67]...|(896,[0,16,26,67]...|
# |j-JE8jELAHBbg6MKe...|[Restaurants, Sea...|(896,[0,55,83,89,...|(896,[0,55,83,89,...|
# |Bv1AGJ3p_X35tqUcV...|[Chinese, Restaur...|(896,[0,2,27],[1....|(896,[0,2,27],[1....|
# |TOfthw3SAWmp7E1na...|[Beauty & Spas, M...|(896,[3,6,52,120]...|(896,[3,6,52,120]...|
# |m8o3OrY0DWfqvk820...|[Data Recovery, C...|(896,[1,9,118,122...|(896,[1,9,118,122...|
# |gzDTRVYgHDyUmKmRu...|[Local Services, ...|(896,[1,9,101,118...|(896,[1,9,101,118...|
# |Qi2vOSs7AIeen_zrW...|[Diners, American...|(896,[0,13,29,99]...|(896,[0,13,29,99]...|
# +--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
restaurants_idf = (categories_idf
                  .where(expr("array_contains(categories, 'Restaurants')")))
                          
restaurants_idf.head(10)
# Out:
# [Row(business_id=u'BzXtEUHu86ju9ttE-X3saw', categories=[u'Italian', u'Food Delivery Services', u'Food', u'Pizza', u'Greek', u'Restaurants'], category_count=SparseVector(896, {0: 1.0, 2: 1.0, 15: 1.0, 21: 1.0, 114: 1.0, 155: 1.0}), categories_idf=SparseVector(896, {0: 1.0868, 2: 1.9145, 15: 3.3137, 21: 3.5525, 114: 5.079, 155: 5.4413})),
#  Row(business_id=u'3cu4pGmmMf-ZSL69nP1lKQ', categories=[u'Food', u'Specialty Food', u'Ethnic Food', u'Middle Eastern', u'Restaurants'], category_count=SparseVector(896, {0: 1.0, 2: 1.0, 31: 1.0, 116: 1.0, 140: 1.0}), categories_idf=SparseVector(896, {0: 1.0868, 2: 1.9145, 31: 3.7675, 116: 5.0846, 140: 5.2651})),
#  Row(business_id=u'L6_B4Z_29vjBTUPWFWZu3Q', categories=[u'Breakfast & Brunch', u'Restaurants'], category_count=SparseVector(896, {0: 1.0, 29: 1.0}), categories_idf=SparseVector(896, {0: 1.0868, 29: 3.6991})),
#  Row(business_id=u'bYvm_7jKKaewN2kFLFF4TA', categories=[u'Sandwiches', u'Restaurants'], category_count=SparseVector(896, {0: 1.0, 16: 1.0}), categories_idf=SparseVector(896, {0: 1.0868, 16: 3.3154})),
#  Row(business_id=u'9NwXHbKyJOhX9nxjRi0AcQ', categories=[u'Pretzels', u'Food Stands', u'Restaurants', u'Food'], category_count=SparseVector(896, {0: 1.0, 2: 1.0, 307: 1.0, 554: 1.0}), categories_idf=SparseVector(896, {0: 1.0868, 2: 1.9145, 307: 6.412, 554: 7.7487})),
#  Row(business_id=u'gU8H-yYJEByT7b8ZvHs16g', categories=[u'Sports Bars', u'Nightlife', u'Burgers', u'Dive Bars', u'Restaurants', u'Bars'], category_count=SparseVector(896, {0: 1.0, 5: 1.0, 7: 1.0, 24: 1.0, 59: 1.0, 186: 1.0}), categories_idf=SparseVector(896, {0: 1.0868, 5: 2.6143, 7: 2.7611, 24: 3.6151, 59: 4.4679, 186: 5.6434})),
#  Row(business_id=u'cfggUk66F01Av4YWZJXcnA', categories=[u'Bars', u'American (New)', u'Cinema', u'Arts & Entertainment', u'Dinner Theater', u'Cocktail Bars', u'Nightlife', u'Restaurants'], category_count=SparseVector(896, {0: 1.0, 5: 1.0, 7: 1.0, 20: 1.0, 26: 1.0, 143: 1.0, 219: 1.0}), categories_idf=SparseVector(896, {0: 1.0868, 5: 2.6143, 7: 2.7611, 20: 3.4158, 26: 3.681, 143: 5.2814, 219: 5.8844})),
#  Row(business_id=u'35AWV2l8s2DbBxKbexPU7A', categories=[u'Restaurants', u'Chinese'], category_count=SparseVector(896, {0: 1.0, 27: 1.0}), categories_idf=SparseVector(896, {0: 1.0868, 27: 3.6838})),
#  Row(business_id=u'gN8H5X-k7GHbAXm97q0kkg', categories=[u'Restaurants', u'Food', u'Barbeque', u'Food Trucks', u'Sandwiches'], category_count=SparseVector(896, {0: 1.0, 2: 1.0, 16: 1.0, 83: 1.0, 179: 1.0}), categories_idf=SparseVector(896, {0: 1.0868, 2: 1.9145, 16: 3.3154, 83: 4.7212, 179: 5.5973})),
#  Row(business_id=u'ZU6pUJNBGXQZrWD9zEHtuQ', categories=[u'Restaurants', u'Chinese'], category_count=SparseVector(896, {0: 1.0, 27: 1.0}), categories_idf=SparseVector(896, {0: 1.0868, 27: 3.6838}))]

# %%
def dot_prod(v1, v2): 
    return float(v1.dot(v2))
#     return np.dot(v1.toArray(), v2.toArray())

# def join_cond(t1_bid, t1_idf, t2_bid, t2_idf):
    

f = udf(dot_prod, FloatType())
# n = udf(lambda v1: v1.norm(2), FloatType())

restaurant_network = (restaurants_idf.select(["business_id", "categories_idf"]).alias("t1")
           .join(restaurants_idf.select(["business_id", "categories_idf"]).alias("t2"), col("t1.business_id") < col("t2.business_id"))
           .select([col("t1.business_id"), col("t2.business_id"), f(col("t1.categories_idf"), col("t2.categories_idf")).alias("dot")])
           .orderBy(["dot"], ascending=[0])
            )
#            .cache())
           
# network = network.filter(col("dot") > 0).orderBy([col("dot")], ascending=[0])
#            .select([col("t1.business_id"), n(col("t1.categories_idf")).alias("dot")]))
restaurant_network.head(20)

# %%
kmeans_idf = KMeans(k=100, featuresCol="categories_idf", predictionCol="cluster_num_pred_idf")
kmeans_idf_model = kmeans_idf.fit(categories_idf)
summary = kmeans_idf_model.summary

print(summary.clusterSizes)
# print(kmeans_idf_model.clusterCenters())

top_clusters_cats = [(np.where(x > 0.9)[0], x[np.where(x > 0.9)]) for x in kmeans_idf_model.clusterCenters()]
sorted([[(cv_model.vocabulary[elem[0]], elem[1]) for elem in zip(arr, vals)] for (arr, vals) in top_clusters_cats])
# Out:
# [2380, 3216, 910, 1104, 1684, 1501, 648, 2512, 608, 1230, 2280, 1186, 1750, 2840, 879, 167, 837, 1522, 1304, 1202, 609, 606, 791, 2436, 1522, 169, 29104, 605, 2279, 828, 161, 2819, 1205, 699, 1309, 900, 676, 428, 554, 278, 1329, 262, 1813, 1246, 249, 3313, 842, 2413, 545, 284, 3149, 1102, 625, 889, 896, 510, 1375, 1021, 1718, 4518, 666, 290, 100, 311, 630, 533, 1003, 1706, 319, 155, 666, 774, 584, 1317, 547, 203, 753, 288, 2571, 905, 907, 858, 757, 269, 656, 5141, 1346, 813, 344, 3200, 258, 869, 279, 332, 2336, 365, 921, 2064, 690, 1184]
# [[],
#  [(u'Active Life', 3.0625272830502825),
#   (u'Fitness & Instruction', 3.78572126233838),
#   (u'Gyms', 3.4567221248193247),
#   (u'Trainers', 4.2531831333548018)],
#  [(u'Active Life', 3.062527283050287),
#   (u'Fitness & Instruction', 3.7857212623383876),
#   (u'Gyms', 4.4421505053531591)],
#  [(u'Active Life', 3.0625272830502932),
#   (u'Fitness & Instruction', 1.0714305459448248),
#   (u'Parks', 0.99763051176085082)],
#  [(u'Active Life', 3.0625272830502981),
#   (u'Arts & Entertainment', 1.2638568513133326),
#   (u'Fitness & Instruction', 3.7857212623383707),
#   (u'Education', 1.5748638414360183),
#   (u'Specialty Schools', 1.7959738135481464),
#   (u'Performing Arts', 1.646335662411919),
#   (u'Dance Studios', 6.1954972244656563),
#   (u'Dance Schools', 2.1847260255472771)],
#  [(u'Active Life', 3.0625272830502985),
#   (u'Parks', 1.7800468223134962),
#   (u'Hiking', 6.7400186084690681)],
#  [(u'Arts & Entertainment', 3.4158293278738698),
#   (u'Performing Arts', 5.1364469986979078)],
#  [(u'Automotive', 2.8215458591930451),
#   (u'Auto Repair', 3.2218358099659281),
#   (u'Car Dealers', 4.6664767889164205),
#   (u'Auto Parts & Supplies', 4.6813801944189981)],
#  [(u'Automotive', 2.8215458591930482),
#   (u'Car Wash', 4.5213647007584123),
#   (u'Auto Detailing', 3.0629955321313336)],
#  [(u'Automotive', 2.8215458591930491),
#   (u'Motorcycle Dealers', 5.2236272350055888),
#   (u'Motorcycle Repair', 4.1016319165484587),
#   (u'Motorcycle Gear', 1.1528890817452184)],
#  [(u'Automotive', 2.8215458591930496),
#   (u'Auto Repair', 1.6088219930587131),
#   (u'Car Dealers', 4.6664767889164214)],
#  [(u'Automotive', 2.82154585919305),
#   (u'Auto Parts & Supplies', 4.6813801944190123)],
#  [(u'Automotive', 2.82154585919305),
#   (u'Auto Repair', 2.2298209656061014),
#   (u'Body Shops', 5.2504246775113801)],
#  [(u'Automotive', 2.82154585919305),
#   (u'Auto Repair', 2.7177629268424526),
#   (u'Tires', 4.5706288301262852),
#   (u'Oil Change Stations', 2.2517845264327838)],
#  [(u'Automotive', 2.8215458591930505),
#   (u'Auto Repair', 3.4060316732303062),
#   (u'Oil Change Stations', 1.6806278076617276)],
#  [(u'Beauty & Spas', 2.3497904046817717),
#   (u'Hair Salons', 2.9899696192469207),
#   (u'Day Spas', 0.97711628210875545)],
#  [(u'Beauty & Spas', 2.3497904046817721),
#   (u'Hair Salons', 3.3432010030833545),
#   (u'Barbers', 2.3110687168844768),
#   (u'Hair Stylists', 3.0270731704551501),
#   (u"Men's Hair Salons", 1.433658648300195)],
#  [(u'Beauty & Spas', 2.3497904046817721),
#   (u'Hair Salons', 3.3872291111134318),
#   (u'Hair Stylists', 2.8517384012350941),
#   (u'Makeup Artists', 1.1866315353672836),
#   (u'Hair Extensions', 5.2595089143955764),
#   (u'Blow Dry/Out Services', 1.730231682014487)],
#  [(u'Beauty & Spas', 2.3497904046817726),
#   (u'Tattoo', 5.3124836052573166),
#   (u'Piercing', 2.8086238744537901)],
#  [(u'Beauty & Spas', 2.3497904046817735),
#   (u'Nail Salons', 3.6787375309562917)],
#  [(u'Beauty & Spas', 2.3497904046817748),
#   (u'Hair Removal', 1.9184453876907677),
#   (u'Skin Care', 2.3637019596542612),
#   (u'Day Spas', 0.90474477711634438),
#   (u'Cosmetics & Beauty Supply', 1.2857591390955738),
#   (u'Medical Spas', 0.99520431201768922)],
#  [(u'Event Planning & Services', 2.9905145325386959),
#   (u'Hotels & Travel', 3.3874349359572116),
#   (u'Hotels', 4.0532202312091608)],
#  [(u'Event Planning & Services', 2.9905145325386999),
#   (u'Venues & Event Spaces', 2.3353812509729166),
#   (u'Party & Event Planning', 2.2647137451100776),
#   (u'Wedding Planning', 0.95358478349398013)],
#  [(u'Event Planning & Services', 2.9905145325387013),
#   (u'Photographers', 5.4127875885986585),
#   (u'Session Photography', 4.7075269204393857),
#   (u'Event Photography', 5.6994955537148213)],
#  [(u'Event Planning & Services', 2.9905145325387017),
#   (u'Photographers', 5.157316787956832),
#   (u'Session Photography', 1.7952380161127084),
#   (u'Video/Film Production', 0.94993659948860298),
#   (u'Videographers', 1.0895546719450133)],
#  [(u'Financial Services', 4.4147515311650345),
#   (u'Banks & Credit Unions', 5.1376645509233683),
#   (u'Mortgage Brokers', 1.0085506336117231)],
#  [(u'Food', 1.912646155444913),
#   (u'Automotive', 1.0619019883859551),
#   (u'Cosmetics & Beauty Supply', 1.114313760226658),
#   (u'Drugstores', 1.3718522882847282),
#   (u'Convenience Stores', 4.7939303269622986),
#   (u'Gas & Service Stations', 1.8796115075130486),
#   (u'Photography Stores & Services', 1.0943156762514612)],
#  [(u'Food', 1.9145323942569821),
#   (u'Coffee & Tea', 1.9810750717283176),
#   (u'Donuts', 5.5568489317729171)],
#  [(u'Food', 1.9145323942569821),
#   (u'Specialty Food', 3.7674947553460916),
#   (u'Grocery', 1.5908836925360346),
#   (u'Fruits & Veggies', 6.2024937783478418),
#   (u'Farmers Market', 1.4422783152926331)],
#  [(u'Food', 1.9145323942569825),
#   (u'Bakeries', 3.2682585611849819),
#   (u'Desserts', 2.9327397478415866),
#   (u'Cupcakes', 6.734153489016661)],
#  [(u'Food', 1.9145323942569825),
#   (u'Specialty Food', 3.767494755346092),
#   (u'Desserts', 1.3897871508497479),
#   (u'Chocolatiers & Shops', 6.0676745555388889),
#   (u'Candy Stores', 1.7638590362296405)],
#  [(u'Food', 1.9145323942569832),
#   (u'Specialty Food', 3.7674947553460916),
#   (u'Cheese Shops', 6.7759506176951243)],
#  [(u'Food', 1.9145323942569865), (u'Coffee & Tea', 3.3388212268069131)],
#  [(u'Food', 1.9145323942569865), (u'Desserts', 4.2242214716617159)],
#  [(u'Food', 1.9145323942569874), (u'Bakeries', 3.9470507238926369)],
#  [(u'Food', 1.9145323942569876),
#   (u'Desserts', 1.0620899700178035),
#   (u'Ice Cream & Frozen Yogurt', 4.2834509169995414)],
#  [(u'Food', 1.9145323942569878),
#   (u'Specialty Food', 3.7655108191926661),
#   (u'Ethnic Food', 1.7522677580340218),
#   (u'Health Markets', 1.0787308047645965),
#   (u'Meat Shops', 0.90713390881584643),
#   (u'Imported Food', 1.0561477589296833)],
#  [(u'Food', 1.9145323942569887),
#   (u'Juice Bars & Smoothies', 4.9591020251657181)],
#  [(u'Food', 1.9145323942569892),
#   (u'Nightlife', 0.90799569148502157),
#   (u'Bars', 0.91150709366439298),
#   (u'Beer', 4.5093718971917376),
#   (u'Wine & Spirits', 4.5093718971917376)],
#  [(u'Health & Medical', 2.6055855841655187),
#   (u'Doctors', 1.125531828653497),
#   (u'Professional Services', 1.3288744460016195),
#   (u'Counseling & Mental Health', 5.8251339170158092),
#   (u'Life Coach', 2.1054738320587094),
#   (u'Hypnosis/Hypnotherapy', 1.0358178907125657)],
#  [(u'Health & Medical', 2.6188793881663641), (u'Doctors', 2.1243310668040229)],
#  [(u'Health & Medical', 2.6188793881663663),
#   (u'Dentists', 4.073607729272215),
#   (u'General Dentistry', 3.3496773326123179),
#   (u'Cosmetic Dentists', 2.4159842037736525),
#   (u'Orthodontists', 1.3458673539072603),
#   (u'Oral Surgeons', 1.0421906419559397)],
#  [(u'Home Services', 2.5282935757862841),
#   (u'Local Services', 1.6642757665758887),
#   (u'Professional Services', 1.2361617704068462),
#   (u'Home Cleaning', 4.2968393360740951),
#   (u'Carpet Cleaning', 2.6774214795116804),
#   (u'Office Cleaning', 1.7980008369508604)],
#  [(u'Home Services', 2.5484050019573106),
#   (u'Contractors', 1.135329963188014),
#   (u'Heating & Air Conditioning/HVAC', 1.4435932075101403),
#   (u'Plumbing', 5.120209354613606),
#   (u'Water Heater Installation/Repair', 1.2200668945683564)],
#  [(u'Home Services', 2.5484050019573115),
#   (u'Real Estate', 3.8008566864034603),
#   (u'Apartments', 0.96195512988343512),
#   (u'Real Estate Services', 1.895793613529247),
#   (u'Real Estate Agents', 1.2958149362568059),
#   (u'Property Management', 5.5007922256912334)],
#  [(u'Home Services', 2.5484050019573132),
#   (u'Real Estate', 3.8008566864034741),
#   (u'Apartments', 2.6035582553686418),
#   (u'Real Estate Services', 1.3031247736084883),
#   (u'Real Estate Agents', 1.118272680346603)],
#  [(u'Hotels & Travel', 3.3874349359572093),
#   (u'Transportation', 5.2268324954945511),
#   (u'Limos', 2.1479745072164023),
#   (u'Airport Shuttles', 2.0329437893994413),
#   (u'Taxis', 1.8395811340049473),
#   (u'Public Transportation', 1.5520116688756906)],
#  [(u'Hotels & Travel', 3.3874349359572107),
#   (u'Car Rental', 5.4003843288152469)],
#  [(u'Local Services', 2.8531141632689265),
#   (u'Professional Services', 2.1091827293445822),
#   (u'Printing Services', 4.9487543846556319),
#   (u'Shipping Centers', 3.2921041315251078),
#   (u'Graphic Design', 2.0201246948842626),
#   (u'Notaries', 2.3615619197394428),
#   (u'Signmaking', 1.6432477377001549)],
#  [(u'Local Services', 2.8720089590521658),
#   (u'Dry Cleaning & Laundry', 1.0271493676165122)],
#  [(u'Nightlife', 2.6143083869687471), (u'Bars', 2.71451380795768)],
#  [(u'Nightlife', 2.6143083869687493),
#   (u'Dance Clubs', 0.912670840562533),
#   (u'Adult Entertainment', 6.2626889391312703)],
#  [(u'Nightlife', 2.6143083869687498),
#   (u'Bars', 1.6151573069148824),
#   (u'Arts & Entertainment', 3.4158293278738796),
#   (u'Music Venues', 5.1507834033525013)],
#  [(u'Nightlife', 2.6143083869687511),
#   (u'Bars', 1.0008125283874925),
#   (u'Arts & Entertainment', 3.4158293278738721),
#   (u'Venues & Event Spaces', 0.95487586824508386),
#   (u'Performing Arts', 1.0448306340821139),
#   (u'Music Venues', 5.1507834033524995),
#   (u'Dance Clubs', 1.5290660390939441)],
#  [(u'Nightlife', 2.6143083869687533),
#   (u'Bars', 1.3943314308448584),
#   (u'Lounges', 0.91682696254403839),
#   (u'Dance Clubs', 5.263776010686251)],
#  [(u'Nightlife', 2.6143083869687542),
#   (u'Bars', 2.7611069045583916),
#   (u'Lounges', 4.7353640024181702)],
#  [(u'Nightlife', 2.6143083869687547),
#   (u'Bars', 2.7611069045583911),
#   (u'Italian', 0.97932442651484441),
#   (u'Wine Bars', 5.1038814896797096)],
#  [(u'Nightlife', 2.6143083869687564),
#   (u'Bars', 2.7611069045583982),
#   (u'Pubs', 4.3078338494442834)],
#  [(u'Nightlife', 2.6143083869687569),
#   (u'Bars', 2.7611069045583916),
#   (u'American (Traditional)', 1.6734268090263487),
#   (u'Sports Bars', 4.4678927229597321)],
#  [(u'Pets', 3.9026616120751969),
#   (u'Pet Services', 2.2202168874250878),
#   (u'Pet Groomers', 1.2940651758930219),
#   (u'Veterinarians', 2.5653329894027674),
#   (u'Pet Boarding/Pet Sitting', 1.1985543717994085),
#   (u'Pet Stores', 1.8213794060129671)],
#  [(u'Pets', 3.9026616120751987),
#   (u'Pet Services', 4.3341339456372241),
#   (u'Pet Groomers', 3.4721784840169274),
#   (u'Pet Boarding/Pet Sitting', 2.7465746288718718),
#   (u'Pet Stores', 1.0525305097922375),
#   (u'Pet Training', 1.1994455715584764),
#   (u'Dog Walkers', 1.0358930352285158)],
#  [(u'Pets', 3.9026616120752005),
#   (u'Pet Services', 2.934772312965114),
#   (u'Pet Training', 1.627790175616715),
#   (u'Animal Shelters', 2.5792604414143234)],
#  [(u'Professional Services', 3.7940328385843358),
#   (u'Lawyers', 5.55865235877204),
#   (u'Personal Injury Law', 2.83462082997575),
#   (u'Criminal Defense Law', 2.1515704977896282),
#   (u'Divorce & Family Law', 1.973966659486371),
#   (u'DUI Law', 1.5628960108571663),
#   (u'Legal Services', 0.97634182343187548),
#   (u'Bankruptcy Law', 1.4919143073057644),
#   (u'General Litigation', 1.3476927999549513),
#   (u'Estate Planning Law', 1.1528249103897867),
#   (u'Real Estate Law', 0.99865638459180694),
#   (u'Business Law', 0.95900383934483957)],
#  [(u'Public Services & Government', 4.9433691539468141),
#   (u'Libraries', 1.527678446764086),
#   (u'Landmarks & Historical Buildings', 1.4640478465209872),
#   (u'Post Offices', 1.4038480811532597)],
#  [(u'Restaurants', 1.0867866700578275), (u'French', 5.0689876851271558)],
#  [(u'Restaurants', 1.0867866700578277),
#   (u'Indian', 4.2229826679910571),
#   (u'Pakistani', 6.0858568746220891)],
#  [(u'Restaurants', 1.0867866700578279),
#   (u'Chinese', 1.1668421642083739),
#   (u'Buffets', 5.3091446157160718)],
#  [(u'Restaurants', 1.0867866700578279),
#   (u'Nightlife', 1.0728038400708417),
#   (u'Bars', 1.1110430173721058),
#   (u'Tapas/Small Plates', 6.088919664152626),
#   (u'Tapas Bars', 1.7336391955505182),
#   (u'Spanish', 1.0934477024076379)],
#  [(u'Restaurants', 1.0867866700578286),
#   (u'Canadian (New)', 4.715747837923205)],
#  [(u'Restaurants', 1.0867866700578286), (u'Caribbean', 5.7316314113936722)],
#  [(u'Restaurants', 1.0867866700578286),
#   (u'Fast Food', 1.6157313415484338),
#   (u'Chicken Wings', 1.7077923855644701),
#   (u'Chicken Shop', 6.8259610382697984)],
#  [(u'Restaurants', 1.0867866700578286), (u'Japanese', 4.2477859185890106)],
#  [(u'Restaurants', 1.0867866700578286),
#   (u'Seafood', 1.32976782090376),
#   (u'Steakhouses', 4.7618609359533108)],
#  [(u'Restaurants', 1.0867866700578286),
#   (u'Vegetarian', 5.0752046751238904),
#   (u'Vegan', 2.1208586755400303)],
#  [(u'Restaurants', 1.0867866700578288), (u'Indian', 4.7659375824470533)],
#  [(u'Restaurants', 1.0867866700578288),
#   (u'Mediterranean', 2.2243893787120386),
#   (u'Greek', 5.0789933272444641)],
#  [(u'Restaurants', 1.086786670057829),
#   (u'American (Traditional)', 1.2134160703377304),
#   (u'Breakfast & Brunch', 1.8986380642895462),
#   (u'Diners', 4.9221328346487949)],
#  [(u'Restaurants', 1.086786670057829), (u'Barbeque', 4.7212016886056594)],
#  [(u'Restaurants', 1.0867866700578293),
#   (u'Cafes', 1.1262194250780186),
#   (u'Bistros', 7.2508442322350666)],
#  [(u'Restaurants', 1.0867866700578297),
#   (u'Japanese', 2.7722392310791411),
#   (u'Sushi Bars', 4.4421505053531671)],
#  [(u'Restaurants', 1.0867866700578299),
#   (u'Sandwiches', 2.1820863236111308),
#   (u'Delis', 4.5821193249178904)],
#  [(u'Restaurants', 1.0867866700578304),
#   (u'Fast Food', 0.90757517690867595),
#   (u'Pizza', 1.5335666187943677),
#   (u'Chicken Wings', 4.426319040136474)],
#  [(u'Restaurants', 1.0867866700578304),
#   (u'Fast Food', 2.1400917455826178),
#   (u'Burgers', 3.5583587780216592)],
#  [(u'Restaurants', 1.086786670057831),
#   (u'American (Traditional)', 3.2979051190683837)],
#  [(u'Restaurants', 1.086786670057831), (u'Chinese', 3.6838001309824726)],
#  [(u'Restaurants', 1.086786670057831),
#   (u'Sandwiches', 1.5699404875650969),
#   (u'Breakfast & Brunch', 1.3679954144750632),
#   (u'Cafes', 2.3477290283661953),
#   (u'Salad', 1.5757794311485711),
#   (u'Soup', 0.96680689182070079)],
#  [(u'Restaurants', 1.0867866700578315),
#   (u'Pizza', 1.4962264234854137),
#   (u'Italian', 3.5524513510832518)],
#  [(u'Restaurants', 1.0867866700578317), (u'Pizza', 3.3136504884603606)],
#  [(u'Shopping', 1.1795895878505422),
#   (u'Local Services', 2.8720089590521622),
#   (u'Electronics', 1.3446137342567455),
#   (u'IT Services & Computer Repair', 5.0567961983689829),
#   (u'Mobile Phones', 1.6637906627085361),
#   (u'Electronics Repair', 2.0198838416790759),
#   (u'Computers', 1.6172243549471386),
#   (u'Mobile Phone Repair', 2.6000373981127427)],
#  [(u'Shopping', 1.2010758562515476),
#   (u'Health & Medical', 2.6188793881663717),
#   (u'Doctors', 1.0449334000039392),
#   (u'Optometrists', 5.0479110571042387),
#   (u'Eyewear & Opticians', 3.3702610098252497),
#   (u'Ophthalmologists', 1.5983280951830954)],
#  [(u'Shopping', 1.8560142006018516),
#   (u'Music & Video', 4.8610026942437852),
#   (u'Books', 4.8610026942437852),
#   (u'Mags', 4.8610026942437852),
#   (u'Bookstores', 2.4840715365410073),
#   (u'Music & DVDs', 1.5384308409204344),
#   (u'Videos & Video Game Rental', 1.3779351857028161),
#   (u'Comic Books', 1.055906536771456)],
#  [(u'Shopping', 1.856014200601853),
#   (u'Fashion', 3.2059027670854241),
#   (u'Department Stores', 4.6865148128855489),
#   (u'Discount Store', 1.3256721845552322)],
#  [(u'Shopping', 1.8560142006018532),
#   (u'Fashion', 3.2059027670854223),
#   (u"Women's Clothing", 2.364099352999105),
#   (u"Men's Clothing", 3.9235334792606538),
#   (u"Children's Clothing", 1.6987943758820314)],
#  [(u'Shopping', 1.8560142006018532),
#   (u'Fashion', 3.2059027670854263),
#   (u"Women's Clothing", 2.8799505547744824),
#   (u'Accessories', 4.3485965716004529),
#   (u"Men's Clothing", 1.4478467386402138)],
#  [(u'Shopping', 1.8560142006018534),
#   (u'Fashion', 3.0643289086900181),
#   (u"Women's Clothing", 1.0891461741697979),
#   (u'Sporting Goods', 1.364685946598309),
#   (u'Shoe Stores', 1.499336297699573),
#   (u'Sports Wear', 1.3134825371862768)],
#  [(u'Shopping', 1.8560142006018536),
#   (u'Event Planning & Services', 0.91522106123004821),
#   (u'Flowers & Gifts', 4.5473796926241663),
#   (u'Arts & Crafts', 1.0417186355671353),
#   (u'Florists', 2.9020728940080978),
#   (u'Gift Shops', 1.7111928204924256),
#   (u'Cards & Stationery', 1.2084342735149192)],
#  [(u'Shopping', 1.8560142006018538),
#   (u'Home & Garden', 3.5582950492321612),
#   (u'Furniture Stores', 1.6316154645067429),
#   (u'Home Decor', 1.3577510744498082)],
#  [(u'Shopping', 1.8560142006018578),
#   (u'Fashion', 1.0492045419552325),
#   (u'Sewing & Alterations', 0.90493865749484781),
#   (u'Bridal', 5.8097089554155739)],
#  [(u'Shopping', 1.8560142006018583),
#   (u'Home & Garden', 1.1902747523839985),
#   (u'Furniture Stores', 0.92412803238571939),
#   (u'Antiques', 5.8572238310230906)],
#  [(u'Shopping', 1.8560142006018592),
#   (u'Fashion', 3.2059027670854214),
#   (u'Used', 5.5460961399966502),
#   (u'Vintage & Consignment', 5.5460961399966502),
#   (u'Thrift Stores', 1.4316267628010175),
#   (u'Antiques', 0.92482481542469863)]]
